# %% [markdown]
# ### explore data
# #### binding energy

# %% [markdown]
# ### Prepare data for PyTorch

# %%
import torch
import torch.utils.data as td
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

def loaddata(batchsize):
    x = np.load('./Data/datax-ORR.npy')
    y = np.load('./Data/datay.npy')[:, 1]

    #split data
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, random_state=10)

    #create loader for training data and labels
    train_x = torch.Tensor(x_train).float()
    #train_x = train_x.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2]).float()
    #print(train_x.shape)
    train_y = torch.Tensor(y_train).float()

    train_data = td.TensorDataset(train_x, train_y)
    train_loader = td.DataLoader(train_data,batch_size=batchsize, shuffle=True, num_workers=1)

    test_x = torch.Tensor(x_test).float()
    test_y = torch.Tensor(y_test).float()

    test_data = td.TensorDataset(test_x, test_y)
    test_loader = td.DataLoader(test_data, batch_size=batchsize, shuffle=True, num_workers=1)

    return train_loader, test_loader

train_loader, test_loader = loaddata(1)
for datax, datay in train_loader:
    pass

print(datax.shape)
# Out:
# torch.Size([1, 8, 7])

# %% [markdown]
# ### Build training model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv

class DACmetals(nn.Module):
    def __init__(self, feature_num):
        super(DACmetals, self).__init__()
        self.dnn0 = nn.Linear(feature_num, 64)
        self.dnn1 = nn.Linear(64, 128)
        self.dnn2 = nn.Linear(128, 1)

    def forward(self, x):
        x = F.relu(self.dnn0(x))
        x = F.relu(self.dnn1(x))
        x = self.dnn2(x)
        return x

class substrates(nn.Module):
    def __init__(self, feature_num):
        super(substrates, self).__init__()
        self.conv0 = nn.Conv1d(feature_num, 64,3)
        self.conv1 = nn.Conv1d(64, 128, 3)
        self.conv2 = nn.Conv1d(128, 1, 2)

    def forward(self, x):
        x = x.transpose(1, 2)
        x = F.relu(self.conv0(x))
        x = F.relu(self.conv1(x))
        x = self.conv2(x)
        return x.squeeze(2)

class graphNN(nn.Module):
    def __init__(self, feature_num, device="cpu"):
        super(graphNN, self).__init__()
        self.edge_index = torch.tensor(
            [
                [3, 0, 3, 1, 3, 2, 3, 7, 7, 4, 7, 5, 7, 6, 0, 1, 1, 6, 6, 4, 4, 5, 5, 2, 2, 0], 
                [0, 3, 1, 3, 2, 3, 7, 3, 4, 7, 5, 7, 6, 7, 1, 0, 6, 1, 4, 6, 5, 4, 2, 5, 0, 2]
            ], dtype = torch.long
        )

        if device == "gpu":
            self.edge_index = self.edge_index.cuda()

        self.gcnc0 = GCNConv(feature_num, 64)
        self.gcnc1 = GCNConv(64, 96)
        self.gcnc2 = GCNConv(96, 128)

        self.conv1 = nn.Conv1d(128, 64, 1)
        self.conv2 = nn.Conv1d(64, 32, 1)
        self.conv3 = nn.Conv1d(32, 1, 1)
        self.pool = nn.AdaptiveMaxPool1d(1)

    def forward(self, x):
        x = F.relu(self.gcnc0(x, self.edge_index))
        x = F.relu(self.gcnc1(x, self.edge_index))
        x = F.relu(self.gcnc2(x, self.edge_index))

        x = x.transpose(1, 2)
        
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = self.conv3(x)
        x = self.pool(x)
        x = x.squeeze(2)
        return x


class TopoModel(nn.Module):
    def __init__(self, feature_num, device="cpu"):
        super(TopoModel, self).__init__()
        self.DAC_model = DACmetals(feature_num)
        self.substrate_model = substrates(feature_num)
        self.graph_model = graphNN(feature_num, device)
        self.model0 = nn.Linear(3, 64, 1)
        self.model1 = nn.Linear(64, 128, 1)
        self.model2 = nn.Linear(128, 1, 1)

    def forward(self, x):
        #DAC_out = self.DAC_model(x[:, [3, 7], :])
        DAC_out = self.DAC_model(x[:, 3, :] + x[:, 7, :])
        substrate_out = self.substrate_model(x[:, [0,1,2,4,5,6], :])
        #substrate_feature = self.substrate_feature(x[:, [0, 1, 2, 4, 5, 6], :])
        graph_out = self.graph_model(x)
        
        out = torch.cat([DAC_out, substrate_out, graph_out], dim=1)
        out = F.relu(self.model0(out))
        out = F.relu(self.model1(out))
        out = self.model2(out)
        return out

inputs = torch.randn([16, 8, 11]).float()
print(inputs.shape)

model = TopoModel(inputs.shape[2])
outputs = model(inputs)
print(model)
# Out:
# torch.Size([16, 8, 11])
# TopoModel(
#   (DAC_model): DACmetals(
#     (dnn0): Linear(in_features=11, out_features=64, bias=True)
#     (dnn1): Linear(in_features=64, out_features=128, bias=True)
#     (dnn2): Linear(in_features=128, out_features=1, bias=True)
#   )
#   (substrate_model): substrates(
#     (conv0): Conv1d(11, 64, kernel_size=(3,), stride=(1,))
#     (conv1): Conv1d(64, 128, kernel_size=(3,), stride=(1,))
#     (conv2): Conv1d(128, 1, kernel_size=(2,), stride=(1,))
#   )
#   (graph_model): graphNN(
#     (gcnc0): GCNConv(11, 64)
#     (gcnc1): GCNConv(64, 96)
#     (gcnc2): GCNConv(96, 128)
#     (conv1): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 32, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(32, 1, kernel_size=(1,), stride=(1,))
#     (pool): AdaptiveMaxPool1d(output_size=1)
#   )
#   (model0): Linear(in_features=3, out_features=64, bias=True)
#   (model1): Linear(in_features=64, out_features=128, bias=True)
#   (model2): Linear(in_features=128, out_features=1, bias=True)
# )

# %% [markdown]
# ### Train the model

# %%
def train(model, train_loader, optimizer):
    # set model to train mode
    model.train()
    train_loss, train_error = 0, 0

    index = 0
    for data, target in train_loader:
        #feed forward
        optimizer.zero_grad()
        out = model(data)
        loss = loss_criteria(out, target)
        error = error_criteria(out, target)

        # backpropagate
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_error += error.item()
        index += 1

    avg_loss, avg_error = (train_loss / index), (train_error / index)
    print("training set: average loss: {}, error: {}".format(avg_loss, avg_error))
    return avg_loss, avg_error


def test(model, test_loader):
    # set model to test mode
    model.eval()
    test_loss, test_error = 0, 0
    
    with torch.no_grad():
        index = 0
        for data, target in test_loader:
            out = model(data)
            loss = loss_criteria(out, target)
            error = error_criteria(out, target)

            test_loss += loss.item()
            test_error += error.item()
            index += 1
            
        avg_loss, avg_error = (test_loss/index), (test_error/index)
        print("test set: average loss: {}, error:{}".format(avg_loss, avg_error))
        return avg_loss, avg_error

# %% [markdown]
# #### Train the model

# %%
import torch.nn as nn

# specify the loss criteria
class MyError(nn.Module):
    def __init__(self):
        super(MyError, self).__init__()
    def forward(self, pred, real):
        return torch.mean(torch.abs(torch.sub(pred,real)/real))

# load model
feature_num = 7
model = TopoModel(feature_num)

# error and loss
error_criteria = MyError()
loss_criteria = nn.MSELoss(reduction="mean")

# load data
batchsize = 1
train_loader, test_loader = loaddata(batchsize)

# set optimizer
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
optimizer.zero_grad()

# track the training
epoch_nums = []
training_loss, training_error = [], []
testing_loss, testing_error = [], []

epoch = 150 
for epoch in range(1, epoch+1):
    print("Epoch: {}".format(epoch))
    train_loss, train_error = train(model, train_loader, optimizer)
    test_loss, test_error = test(model, test_loader)

    epoch_nums.append(epoch)
    training_loss.append(train_loss)
    training_error.append(train_error)
    
    testing_loss.append(test_loss)
    testing_error.append(test_error)
# Out:
# Epoch: 1
# C:\Users\lpwu\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# training set: average loss: 2.166863160500907, error: 3.428239311545622
# test set: average loss: 1.4358188209977623, error:6.0203810930252075
# Epoch: 2
# training set: average loss: 1.9194536190969074, error: 3.212726182572078
# test set: average loss: 3.091224022494215, error:1.3397275660600927
# Epoch: 3
# training set: average loss: 1.7565953841279225, error: 2.8866768609150313
# test set: average loss: 2.0797339590527475, error:1.7260674743188753
# Epoch: 4
# training set: average loss: 1.7745507845305384, error: 2.6800117925769884
# test set: average loss: 1.283380316615876, error:5.429868194378084
# Epoch: 5
# training set: average loss: 1.6131859915995619, error: 3.0897396899657905
# test set: average loss: 1.32400301264392, error:5.634315999017821
# Epoch: 6
# training set: average loss: 1.5274345341729805, error: 2.7397125899122328
# test set: average loss: 1.3375823677763239, error:4.411597437742683
# Epoch: 7
# training set: average loss: 1.7387730832036141, error: 2.7691705462057143
# test set: average loss: 1.3878446293787823, error:5.771135630706946
# Epoch: 8
# training set: average loss: 1.4863627081818778, error: 2.171630044071935
# test set: average loss: 1.2888800697530516, error:4.9505969528108835
# Epoch: 9
# training set: average loss: 1.4053988389773053, error: 2.4956333552450816
# test set: average loss: 2.10443104389641, error:10.432439294126299
# Epoch: 10
# training set: average loss: 1.4620542479374676, error: 2.3562531891075196
# test set: average loss: 1.3411488097076978, error:6.777766249142587
# Epoch: 11
# training set: average loss: 1.3214664064676356, error: 2.5144333318254213
# test set: average loss: 1.5416657777710094, error:4.737071876724561
# Epoch: 12
# training set: average loss: 1.5942318690768844, error: 2.4230617575958604
# test set: average loss: 1.2403239379664417, error:5.996932470032738
# Epoch: 13
# training set: average loss: 1.3514241178733415, error: 2.583556290420529
# test set: average loss: 1.4288447144337826, error:3.1232718587335615
# Epoch: 14
# training set: average loss: 1.4727805556634423, error: 2.5325344022900937
# test set: average loss: 1.7218363044141571, error:3.0458185815562806
# Epoch: 15
# training set: average loss: 1.3676696607231862, error: 2.683119183400413
# test set: average loss: 1.2326163585795358, error:5.798600153894061
# Epoch: 16
# training set: average loss: 1.2737197591802214, error: 2.679530546005117
# test set: average loss: 1.3153341092014064, error:6.939514141115877
# Epoch: 17
# training set: average loss: 1.1844932390058147, error: 2.337629050022224
# test set: average loss: 1.5081874841513734, error:8.444325871351692
# Epoch: 18
# training set: average loss: 1.2751536707972349, error: 2.9795706968026936
# test set: average loss: 1.245558430304906, error:6.6414201927578285
# Epoch: 19
# training set: average loss: 1.1692978633720486, error: 2.138398117071483
# test set: average loss: 1.401446714301225, error:8.101348763952652
# Epoch: 20
# training set: average loss: 1.3079657479325761, error: 2.44321003461373
# test set: average loss: 1.4517148813756648, error:2.8203974130252996
# Epoch: 21
# training set: average loss: 1.1762780866105687, error: 2.367160422829329
# test set: average loss: 1.3087789682073587, error:2.857686461104701
# Epoch: 22
# training set: average loss: 1.3108361226048983, error: 2.158468651663861
# test set: average loss: 1.1997250896982021, error:3.9531064530213675
# Epoch: 23
# training set: average loss: 1.170767180854984, error: 2.592484280854842
# test set: average loss: 1.03892854530568, error:5.411493069052489
# Epoch: 24
# training set: average loss: 1.1353364289339125, error: 2.214122886374389
# test set: average loss: 1.1596717332334567, error:6.889220703496701
# Epoch: 25
# training set: average loss: 1.1063461945693462, error: 2.407192855249741
# test set: average loss: 1.3954131014890865, error:8.426429805914974
# Epoch: 26
# training set: average loss: 1.1411086386445959, error: 2.2624094846483787
# test set: average loss: 0.9835992337514957, error:4.938801907002926
# Epoch: 27
# training set: average loss: 0.8770602816346582, error: 2.4492398994058022
# test set: average loss: 0.968747994189875, error:6.0365370794509845
# Epoch: 28
# training set: average loss: 0.9040075473822207, error: 2.621353060000183
# test set: average loss: 1.0358839994296432, error:5.697932452791267
# Epoch: 29
# training set: average loss: 1.0293804250138237, error: 2.5917003725888206
# test set: average loss: 1.4202682425449085, error:8.555751145506898
# Epoch: 30
# training set: average loss: 0.9493103435728131, error: 2.264050706602575
# test set: average loss: 1.8197636811340945, error:9.822292033880432
# Epoch: 31
# training set: average loss: 0.8694188633971407, error: 2.4808814166142836
# test set: average loss: 0.9521935343574215, error:4.975157431844208
# Epoch: 32
# training set: average loss: 0.8553726191323762, error: 2.3189163635903243
# test set: average loss: 1.0895122170267213, error:1.0418750300175614
# Epoch: 33
# training set: average loss: 0.8169605316594929, error: 2.870009861692779
# test set: average loss: 1.2112146732583318, error:7.059219812146491
# Epoch: 34
# training set: average loss: 0.868826955749668, error: 2.4633309176446345
# test set: average loss: 0.9382501458672373, error:5.826314781663111
# Epoch: 35
# training set: average loss: 0.8057679678394379, error: 2.0534083818260114
# test set: average loss: 0.8600408580435518, error:1.8175356090068817
# Epoch: 36
# training set: average loss: 0.791793522406033, error: 2.384817342302995
# test set: average loss: 0.8482231988960444, error:3.5526446044031115
# Epoch: 37
# training set: average loss: 0.7771145216652258, error: 2.0469095253152774
# test set: average loss: 0.8977237401591588, error:5.544949246492858
# Epoch: 38
# training set: average loss: 0.7580825617011897, error: 2.101800385041861
# test set: average loss: 0.8093861897553628, error:4.588384001412326
# Epoch: 39
# training set: average loss: 0.7010737077004023, error: 2.1107989456446377
# test set: average loss: 1.0207016195894942, error:1.2392283220671945
# Epoch: 40
# training set: average loss: 0.7057173685168892, error: 1.7167949613125528
# test set: average loss: 0.8513054161125587, error:4.3980740283926325
# Epoch: 41
# training set: average loss: 0.7003613867254842, error: 2.968063463487488
# test set: average loss: 1.343844633950438, error:1.1276302966806624
# Epoch: 42
# training set: average loss: 0.8290326275808312, error: 1.844063534961606
# test set: average loss: 0.7651927863318835, error:2.1702034330616393
# Epoch: 43
# training set: average loss: 0.7553815199554265, error: 3.39714576160186
# test set: average loss: 0.879341537042314, error:5.3176424954500465
# Epoch: 44
# training set: average loss: 0.6773603393630765, error: 1.9114446457773737
# test set: average loss: 1.022244980895064, error:4.7137698533220425
# Epoch: 45
# training set: average loss: 0.6017912201636305, error: 2.294615481787332
# test set: average loss: 0.8994974853703752, error:1.8663502393497362
# Epoch: 46
# training set: average loss: 0.716865577812132, error: 2.543701831821818
# test set: average loss: 1.231416269308991, error:1.1570394477910466
# Epoch: 47
# training set: average loss: 0.6777277245055189, error: 1.903059438544733
# test set: average loss: 0.8648124690743215, error:3.9901305123284043
# Epoch: 48
# training set: average loss: 0.6631676043915945, error: 2.1014956126338804
# test set: average loss: 0.9094049820509755, error:4.659388454734451
# Epoch: 49
# training set: average loss: 0.6575661233659819, error: 1.831509817272331
# test set: average loss: 0.916508730766509, error:4.554425790957692
# Epoch: 50
# training set: average loss: 0.6641041554736319, error: 2.241308600091725
# test set: average loss: 0.740910151126665, error:1.7143468245372384
# Epoch: 51
# training set: average loss: 0.6670888341149016, error: 1.8202202798711369
# test set: average loss: 0.8430469802535501, error:4.934397179633379
# Epoch: 52
# training set: average loss: 0.6456443270499846, error: 2.095007321465528
# test set: average loss: 0.8103620560496994, error:2.063421054225829
# Epoch: 53
# training set: average loss: 0.7148691135294314, error: 2.2261108900176625
# test set: average loss: 0.8006252497667733, error:1.6329958024736395
# Epoch: 54
# training set: average loss: 0.7218016662716138, error: 1.878655418472772
# test set: average loss: 0.7807859890162945, error:4.037905187242561
# Epoch: 55
# training set: average loss: 0.5724204334636397, error: 1.9135407305962873
# test set: average loss: 0.6800994341093529, error:2.8369706517292395
# Epoch: 56
# training set: average loss: 0.6766403553446281, error: 1.9393993059373316
# test set: average loss: 1.0835942600067736, error:1.6277535231783986
# Epoch: 57
# training set: average loss: 0.6508765346914401, error: 2.375373854674399
# test set: average loss: 0.9637680574895866, error:1.1909594649655952
# Epoch: 58
# training set: average loss: 0.5800068870085624, error: 1.9488641309711965
# test set: average loss: 0.9149999508323768, error:5.717174507470594
# Epoch: 59
# training set: average loss: 0.6823496260897173, error: 2.4068614730116678
# test set: average loss: 0.8042310668356044, error:4.539282626679374
# Epoch: 60
# training set: average loss: 0.6495971184676023, error: 1.756671943352194
# test set: average loss: 0.9373525700518965, error:1.8283972065481875
# Epoch: 61
# training set: average loss: 0.6772584889249629, error: 1.9514081063040067
# test set: average loss: 1.1651842168204085, error:1.1910446544902191
# Epoch: 62
# training set: average loss: 0.6941123284923328, error: 2.5419441055564675
# test set: average loss: 1.2228636608277965, error:7.353603530054291
# Epoch: 63
# training set: average loss: 0.5949865933346701, error: 1.923065248253988
# test set: average loss: 0.8290054371064899, error:3.3027144567264863
# Epoch: 64
# training set: average loss: 0.6155533418448353, error: 1.944405386444123
# test set: average loss: 1.0870773833893408, error:4.545733409752655
# Epoch: 65
# training set: average loss: 0.6348922708140889, error: 1.687581439653877
# test set: average loss: 0.7928668595591767, error:4.059945697792703
# Epoch: 66
# training set: average loss: 0.7253527441767801, error: 2.2174380375654437
# test set: average loss: 0.7362975204014219, error:2.858179924181766
# Epoch: 67
# training set: average loss: 0.6127444150601107, error: 2.6218255676772513
# test set: average loss: 0.7604635514370683, error:2.742938546670808
# Epoch: 68
# training set: average loss: 0.6554152057416331, error: 2.0648493016982683
# test set: average loss: 0.7798846147941529, error:3.0578379616555242
# Epoch: 69
# training set: average loss: 0.5566630192756747, error: 1.8163071535149355
# test set: average loss: 0.7588326813808332, error:2.6967294812202454
# Epoch: 70
# training set: average loss: 0.580516333101599, error: 2.448300734907389
# test set: average loss: 0.829515555816114, error:3.182024911071898
# Epoch: 71
# training set: average loss: 0.584601690341714, error: 1.872003746064729
# test set: average loss: 0.8059547386623712, error:3.3685398829014352
# Epoch: 72
# training set: average loss: 0.5833425610506537, error: 1.8726224671532692
# test set: average loss: 0.7431415960858835, error:1.5695036297871008
# Epoch: 73
# training set: average loss: 0.5085544223164448, error: 1.6190294376079692
# test set: average loss: 1.0892986233962398, error:6.17121531881599
# Epoch: 74
# training set: average loss: 0.709720269934121, error: 2.579898428611341
# test set: average loss: 0.8935421970270201, error:5.8745871998576655
# Epoch: 75
# training set: average loss: 0.5982625495308668, error: 1.7699838236905634
# test set: average loss: 0.9347544362212324, error:1.063344604542686
# Epoch: 76
# training set: average loss: 0.5938033307791443, error: 1.8887499338103226
# test set: average loss: 0.7324110865774855, error:2.9517858852632344
# Epoch: 77
# training set: average loss: 0.6077243853511096, error: 1.8622315433742187
# test set: average loss: 0.7766731224332438, error:3.425148050300777
# Epoch: 78
# training set: average loss: 0.5304254464791043, error: 1.7540712780408285
# test set: average loss: 1.3455759839400545, error:7.9544279800934925
# Epoch: 79
# training set: average loss: 0.6539407402636016, error: 2.3034514448084336
# test set: average loss: 0.9680512293272032, error:1.2005336596113112
# Epoch: 80
# training set: average loss: 0.6213357466039497, error: 1.883201669750997
# test set: average loss: 1.1018386048187192, error:6.552435669530597
# Epoch: 81
# training set: average loss: 0.7088810353637655, error: 3.026033439076855
# test set: average loss: 0.8512115755842792, error:1.8079180918220017
# Epoch: 82
# training set: average loss: 0.5990861047523367, error: 2.050453096040292
# test set: average loss: 1.0193540868794015, error:0.914054724905226
# Epoch: 83
# training set: average loss: 0.6654627719156906, error: 1.992543693241896
# test set: average loss: 1.0588423702671814, error:1.965783362897734
# Epoch: 84
# training set: average loss: 0.5635309704466092, error: 1.9585020594433444
# test set: average loss: 0.7942454758752623, error:3.2230343295442356
# Epoch: 85
# training set: average loss: 0.6468484725068038, error: 1.8274385454336879
# test set: average loss: 0.8227857677354931, error:4.418196936914076
# Epoch: 86
# training set: average loss: 0.6181894589697094, error: 1.931696560033015
# test set: average loss: 0.6280045727040525, error:1.9167806304629065
# Epoch: 87
# training set: average loss: 0.5805134231031829, error: 1.8854300543433056
# test set: average loss: 0.7051338729599794, error:3.07350996731677
# Epoch: 88
# training set: average loss: 0.49895579168855414, error: 1.9435599821736105
# test set: average loss: 1.4298554187743646, error:1.2392431447127212
# Epoch: 89
# training set: average loss: 0.5701467194350798, error: 1.7627945797925348
# test set: average loss: 0.7834972080529276, error:2.439364839448697
# Epoch: 90
# training set: average loss: 0.660769981030407, error: 2.1091955646210407
# test set: average loss: 1.4817986653522692, error:1.0957660302519798
# Epoch: 91
# training set: average loss: 0.7137085252813449, error: 1.840865923007368
# test set: average loss: 0.6916268629979135, error:3.762678087895943
# Epoch: 92
# training set: average loss: 0.6246483971803173, error: 2.3504739418858662
# test set: average loss: 0.7686349469068874, error:2.0790151527358427
# Epoch: 93
# training set: average loss: 0.6143350025775305, error: 2.0365894650036354
# test set: average loss: 0.7176936820130019, error:1.880626034612457
# Epoch: 94
# training set: average loss: 0.5225908197798006, error: 1.920744330321395
# test set: average loss: 0.7654634271853461, error:1.4871921949088573
# Epoch: 95
# training set: average loss: 0.5978272261692397, error: 1.9034483739060306
# test set: average loss: 0.979989438050931, error:1.4434100474334426
# Epoch: 96
# training set: average loss: 0.6465687356625957, error: 1.66936805780133
# test set: average loss: 0.7374811827515563, error:3.333407678330938
# Epoch: 97
# training set: average loss: 0.5145793685662625, error: 1.4984141528009787
# test set: average loss: 0.7859585177502595, error:1.8675583987496793
# Epoch: 98
# training set: average loss: 0.4734563792550304, error: 1.9596679568756372
# test set: average loss: 0.8354792602686858, error:1.4118497328211863
# Epoch: 99
# training set: average loss: 0.6558393112536123, error: 2.0877339852580916
# test set: average loss: 1.1015298851076902, error:5.303828538085024
# Epoch: 100
# training set: average loss: 0.579117213099341, error: 1.9561207437618577
# test set: average loss: 0.6661508087902095, error:3.2089093601486334
# Epoch: 101
# training set: average loss: 0.4880707138546086, error: 1.6954971974599176
# test set: average loss: 0.9866637131021384, error:4.561566683774193
# Epoch: 102
# training set: average loss: 0.4850747513268914, error: 2.010778086166829
# test set: average loss: 1.18789357934424, error:1.3978327658130891
# Epoch: 103
# training set: average loss: 0.6499105681740502, error: 1.709919540458941
# test set: average loss: 0.8888940987720465, error:1.6983499891228147
# Epoch: 104
# training set: average loss: 0.561666361488642, error: 1.7114830397127663
# test set: average loss: 1.0880184571303997, error:1.1723335994821455
# Epoch: 105
# training set: average loss: 0.6307076034646798, error: 1.9287220619153231
# test set: average loss: 0.9229616846423596, error:0.9763498285578357
# Epoch: 106
# training set: average loss: 0.553651372083823, error: 1.9597892619349295
# test set: average loss: 0.9800509575676793, error:1.6228303395004735
# Epoch: 107
# training set: average loss: 0.5453729303598891, error: 1.714866285691096
# test set: average loss: 0.9291065475240745, error:2.3150884363826156
# Epoch: 108
# training set: average loss: 0.5441189459461839, error: 1.9614616242644842
# test set: average loss: 0.8391174247434618, error:1.4408356761042442
# Epoch: 109
# training set: average loss: 0.6625893308438947, error: 1.7051162854841095
# test set: average loss: 0.8054962314329006, error:1.21645050868392
# Epoch: 110
# training set: average loss: 0.5296660007815717, error: 2.0742542898609826
# test set: average loss: 0.7064859561829103, error:1.8201030666629474
# Epoch: 111
# training set: average loss: 0.5814304427457273, error: 2.1347429978399304
# test set: average loss: 0.6746643778786974, error:1.405620372388512
# Epoch: 112
# training set: average loss: 0.5318678302462103, error: 2.0556461868574845
# test set: average loss: 1.0906133779853917, error:0.9490281037029086
# Epoch: 113
# training set: average loss: 0.5704944304452851, error: 2.2195724785880886
# test set: average loss: 0.8816046261506725, error:0.8865530470179187
# Epoch: 114
# training set: average loss: 0.6741269860516141, error: 2.1962553613153433
# test set: average loss: 0.9620807144092396, error:1.3120277825122078
# Epoch: 115
# training set: average loss: 0.5461683835571989, error: 1.5307370815091417
# test set: average loss: 1.0901006810759606, error:5.785634849841396
# Epoch: 116
# training set: average loss: 0.5002547782246893, error: 1.9088494255651312
# test set: average loss: 0.7241177751792647, error:3.2525268176363573
# Epoch: 117
# training set: average loss: 0.4938653648780124, error: 1.489537771858886
# test set: average loss: 0.8910111124700693, error:2.2745185849085425
# Epoch: 118
# training set: average loss: 0.5086178086439815, error: 1.6786456566434935
# test set: average loss: 0.7945815043786284, error:4.798830331393725
# Epoch: 119
# training set: average loss: 0.5073626461427836, error: 1.7651303205871955
# test set: average loss: 0.7849517791901235, error:1.6769846676227946
# Epoch: 120
# training set: average loss: 0.5126544152520637, error: 1.8679046833713073
# test set: average loss: 0.7541998333273214, error:2.6973056187594517
# Epoch: 121
# training set: average loss: 0.5648305789907351, error: 1.9308374530257424
# test set: average loss: 1.1505895099382744, error:5.347655759710404
# Epoch: 122
# training set: average loss: 0.5353234475847273, error: 1.7674527474384376
# test set: average loss: 0.7004181927758408, error:2.1506249277542033
# Epoch: 123
# training set: average loss: 0.5714528250259263, error: 2.5691478860448114
# test set: average loss: 0.8817010050083304, error:4.599002439373483
# Epoch: 124
# training set: average loss: 0.5240164391659278, error: 1.7869202636677073
# test set: average loss: 0.9301836585832967, error:4.642445476518737
# Epoch: 125
# training set: average loss: 0.444765612968672, error: 1.6457680878796963
# test set: average loss: 0.7902576881299157, error:2.8843935088564954
# Epoch: 126
# training set: average loss: 0.5064668005556996, error: 1.6406841856543906
# test set: average loss: 0.8204262993161441, error:2.541554352889458
# Epoch: 127
# training set: average loss: 0.513055510826075, error: 2.0500667013708154
# test set: average loss: 0.8094732651875852, error:1.1857401607558131
# Epoch: 128
# training set: average loss: 0.5419549054635666, error: 1.624028905735031
# test set: average loss: 0.8043100726758389, error:2.2786440530843617
# Epoch: 129
# training set: average loss: 0.4994537050276676, error: 1.8770329828214016
# test set: average loss: 0.7836677166724257, error:2.2428442114550204
# Epoch: 130
# training set: average loss: 0.4793604350792194, error: 1.6510600944231555
# test set: average loss: 0.8242007960022116, error:1.4253615211281512
# Epoch: 131
# training set: average loss: 0.4677523631336783, error: 1.8047904724720865
# test set: average loss: 0.8605453008187598, error:3.6526820154653654
# Epoch: 132
# training set: average loss: 0.5080540772251197, error: 1.4959619071363703
# test set: average loss: 0.9328011929173954, error:1.56767226010561
# Epoch: 133
# training set: average loss: 0.5637778588972118, error: 1.594608838108161
# test set: average loss: 2.0752387999422757, error:11.15077464354949
# Epoch: 134
# training set: average loss: 0.6583232072369583, error: 1.8914261181489564
# test set: average loss: 0.898758152330831, error:1.5444186472644408
# Epoch: 135
# training set: average loss: 0.5176415592364154, error: 1.5314635511449524
# test set: average loss: 1.201698598638662, error:5.235712694211139
# Epoch: 136
# training set: average loss: 0.5775454048402026, error: 2.002948367106728
# test set: average loss: 0.7915814068005097, error:3.8003155067563057
# Epoch: 137
# training set: average loss: 0.5497654271432907, error: 2.735494676876988
# test set: average loss: 0.7960729693166084, error:3.7917086159189544
# Epoch: 138
# training set: average loss: 0.4824755202846518, error: 1.7295475558610633
# test set: average loss: 0.91619548958757, error:0.9603239354550573
# Epoch: 139
# training set: average loss: 0.7276079544890137, error: 3.1973073809063863
# test set: average loss: 0.968863459601203, error:6.068623024789202
# Epoch: 140
# training set: average loss: 0.6318384664420342, error: 2.055087918409845
# test set: average loss: 1.030980614602514, error:5.210199813048045
# Epoch: 141
# training set: average loss: 0.4592974388489665, error: 1.832181795586075
# test set: average loss: 1.6688172820075933, error:7.786627076359259
# Epoch: 142
# training set: average loss: 0.5329583138052613, error: 2.557734301608798
# test set: average loss: 1.0994794884334422, error:2.1110645389805236
# Epoch: 143
# training set: average loss: 0.5506916961121305, error: 1.8448434361256658
# test set: average loss: 0.8480425349427807, error:5.285331907578641
# Epoch: 144
# training set: average loss: 0.4923035610828578, error: 1.4819379828579258
# test set: average loss: 1.073213179922378, error:5.963847900326881
# Epoch: 145
# training set: average loss: 0.6133820848411687, error: 2.058628231525654
# test set: average loss: 0.6516657107624471, error:3.4929227975921497
# Epoch: 146
# training set: average loss: 0.5178956789399546, error: 2.078075170457305
# test set: average loss: 0.711079286086715, error:1.42628704275315
# Epoch: 147
# training set: average loss: 0.4899529806791406, error: 2.0011208054762393
# test set: average loss: 0.8802294150712745, error:2.684485050927227
# Epoch: 148
# training set: average loss: 0.44853467779139466, error: 1.772227785064024
# test set: average loss: 0.9604372580212536, error:4.039399221513627
# Epoch: 149
# training set: average loss: 0.5139545059433204, error: 1.6246549805626274
# test set: average loss: 1.3662008920477495, error:6.64294536308282
# Epoch: 150
# training set: average loss: 0.6035413595344152, error: 1.8868017717788461
# test set: average loss: 1.143045143064632, error:5.797952586577998

# %%
import matplotlib.pyplot as plt

plt.plot(epoch_nums, training_loss)
plt.plot(epoch_nums, testing_loss)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Training', 'test'], loc='upper right')
plt.show()

plt.savefig("./Models/ORR_loss.png")

# %% [markdown]
# #### save the trained model

# %%
model_file = "./Models/DAC_ORR.pt"
torch.save(model.state_dict(), model_file)
del model
print("model is saved")
# Out:
# model is saved
